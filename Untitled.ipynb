# %%
import numpy as np
import os
DEFAULT_FILENAME_DB='my_face_database_s.npy'
filename=DEFAULT_FILENAME_DB
if os.path.exists(filename):
    data = np.load(filename, allow_pickle=True).item()
    print(data.keys())
    # if data and data['fuming'] is not None:
    #     print(len(data['fuming']))
    #     print(data['fuming'])
    # print(data['fuming'])
    print(len(data['haojin']))
# Out:
# dict_keys(['fuming', 'lufangfang', 'yefang', 'yupeng', 'zhangkai', 'zhangpeng', 'zhengyanfen', 'haojin'])
# 1
